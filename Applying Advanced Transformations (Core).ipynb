# %% [markdown]
# The Task
# Your task is two-fold:
#
# I. Clean the files and combine them into one final DataFrame.
#
# This dataframe should have the following columns:
# - Hero (Just the name of the Hero)
# - Publisher
# - Gender
# - Eye color
# - Race
# - Hair color
# - Height (numeric)
# - Skin color
# - Alignment
# - Weight (numeric)
# - Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.:
#     - Agility
#     - Flight
#     - Superspeed
#     - etc.
#
# Hint: There is a space in "100 kg" or "52.5 cm"

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

## Importing the OS and JSON Modules
import os,json

## Filter ALL warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Super Hero CSV

# %%
# CSV File
sup_hero = pd.read_csv('Data/superhero_info.csv')
sup_hero.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
sup_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
# Duplicate values
print(f'There are {sup_hero.duplicated().sum()} duplicate rows.')
# Out:
# There are 0 duplicate rows.

# %% [markdown]
# Separate the Hero and Publisher

# %%
sup_hero[['Hero', 'Publisher']] = sup_hero['Hero|Publisher'].str.split('|', expand = True)

sup_hero.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
sup_hero = sup_hero.drop(columns=['Hero|Publisher'])
sup_hero.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %% [markdown]
# Separate the Height and Weight

# %%
## examining a single value from the coordinates col
measurements = sup_hero.loc[0,"Measurements"]
print(type(measurements))
measurements
# Out:
# <class 'str'>
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
measurements = measurements.replace("'",'"')
measurements
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
## now we can use json.loads
fixed_measurements = json.loads(measurements)
print(type(fixed_measurements))
fixed_measurements
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
## use .str.replace to replace all single quotes
sup_hero['Measurements'] = sup_hero['Measurements'].str.replace("'",'"')
## Apply the json.loads to the full column
sup_hero['Measurements'] = sup_hero['Measurements'].apply(json.loads)
sup_hero['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
## check a single value after transformation
test_measurements = sup_hero.loc[0, 'Measurements']
print(type(test_measurements))
test_measurements
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
ht_wt = sup_hero['Measurements'].apply(pd.Series)
ht_wt
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# concat ht_wt with original dataframe
sup_hero = pd.concat((sup_hero, ht_wt), axis = 1)
sup_hero.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %% [markdown]
# Remove the old Column

# %%
sup_hero = sup_hero.drop(columns=['Measurements'])
sup_hero.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %%
sup_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    object
#  9   Weight      463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %% [markdown]
# Clean Columns convert data type

# %%
sup_hero['Weight'] = sup_hero['Weight'].str.replace(' kg', '')
sup_hero['Weight'].head(2)
# Out:
# 0    441.0
# 1     65.0
# Name: Weight, dtype: object

# %%
sup_hero['Weight'] = sup_hero['Weight'].astype(float)

# %%
sup_hero['Height'] = sup_hero['Height'].str.replace(' cm', '')
sup_hero['Height'].head(2)
# Out:
# 0    203.0
# 1    191.0
# Name: Height, dtype: object

# %%
sup_hero['Height'] = sup_hero['Height'].astype(float)

# %%
sup_hero.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight
# 0         A-Bomb      Marvel Comics  203.0  441.0
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0
# 2       Abin Sur          DC Comics  185.0   90.0
# 3    Abomination      Marvel Comics  203.0  441.0
# 4  Absorbing Man      Marvel Comics  193.0  122.0

# %%
sup_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    float64
#  9   Weight      463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %% [markdown]
# # Super Powers CSV

# %%
# CSV File
sup_powers = pd.read_csv('Data/superhero_powers.csv')
sup_powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
sup_powers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
# Duplicate values
print(f'There are {sup_powers.duplicated().sum()} duplicate rows.')
# Out:
# There are 0 duplicate rows.

# %%
sup_powers['powers_split'] = sup_powers['Powers'].str.split(',')

# %%
exploded = sup_powers.explode('powers_split')

# %%
cols_to_make = exploded['powers_split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
#        'Enhanced Senses', 'Jump', 'Shapeshifting', 'Elasticity',
#        'Substance Secretion', 'Enhanced Hearing', 'Adaptation', 'Gliding',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Weapon-based Powers', 'Fire Control', 'Enhanced Memory',
#        'Energy Constructs', 'Power Absorption', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Psionic Powers',
#        'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Toxin and Disease Control', 'Empathy',
#        'Animal Control', 'Darkforce Manipulation', 'Time Manipulation',
#        'Reality Warping', 'Web Creation', 'Symbiote Costume',
#        'Telekinesis', 'Levitation', 'Biokinesis', 'Sonar',
#        'Enhanced Touch', 'Seismic Power', 'Energy Armor',
#        'Omnilingualism', 'Radiation Immunity', 'Density Control',
#        'Light Control', 'Illumination', 'Molecular Combustion',
#        'Astral Travel', 'Precognition', 'Intangibility', 'Illusions',
#        'Audio Control', 'Sonic Scream', 'Peak Human Condition',
#        'Vision - Infrared', 'Dexterity', 'Omnitrix', 'Omnipotent',
#        'Possession', 'Energy Resistance', 'Vision - Cryo', 'Mind Control',
#        'Mind Blast', 'Clairvoyance', 'Probability Manipulation',
#        'Death Touch', 'Electrokinesis', 'Gravity Control',
#        'Technopath/Cyberpath', 'Radar Sense', 'Astral Projection',
#        'Cloaking', 'Telepathy Resistance', 'Mind Control Resistance',
#        'Hyperkinesis', 'Spatial Awareness', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance', 'Element Control',
#        'Plant Control', 'Terrakinesis', 'Power Sense', 'Wind Control',
#        'Qwardian Power Ring', 'Echolocation', 'Resurrection', 'The Force',
#        'Summoning', 'Banish', 'Molecular Dissipation',
#        'Electrical Transport', 'Speed Force', 'Grim Reaping',
#        'Portal Creation', 'Vitakinesis', 'Projection', 'Insanity',
#        'Photographic Reflexes', 'Anti-Gravity', 'Thirstokinesis',
#        'Power Nullifier', 'Weather Control', 'Omnipresent', 'Omniscient',
#        'Hair Manipulation', 'Nova Force', 'Odin Force', 'Phoenix Force',
#        'Intuitive aptitude', 'Melting', 'Changing Armor'], dtype=object)

# %%
for col in cols_to_make:
    sup_powers[col] = sup_powers['Powers'].str.contains(col)
sup_powers.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         powers_split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# 0     True         True                False       False      False  ...
# 1     True        False                 True        True       True  ...
# 2     True        False                 True        True       True  ...
# 3    False        False                False       False      False  ...
# 4     True         True                 True       False      False  ...
#
#    Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# 0            False        False       False              False       False
# 1            False        False       False              False       False
# 2            False        False       False              False       False
# 3            False        False       False              False       False
# 4            False        False       False              False       False
#
#    Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0       False          False               False    False           False
# 1       False          False               False    False           False
# 2       False          False               False    False           False
# 3       False          False               False    False           False
# 4       False          False               False    False           False
#
# [5 rows x 170 columns]

# %%
# Drop the unnecessary columns
sup_powers = sup_powers.drop(columns=['Powers', 'powers_split'])
sup_powers.head()
# Out:
#     hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# 1  ...            False        False       False              False
# 2  ...            False        False       False              False
# 3  ...            False        False       False              False
# 4  ...            False        False       False              False
#
#    Nova Force  Odin Force  Phoenix Force  Intuitive aptitude  Melting  \
# 0       False       False          False               False    False
# 1       False       False          False               False    False
# 2       False       False          False               False    False
# 3       False       False          False               False    False
# 4       False       False          False               False    False
#
#    Changing Armor
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 168 columns]

# %% [markdown]
# # Combine Dataframe

# %%
## merging with different column names
hero_df = pd.merge(sup_hero, sup_powers, left_on='Hero', right_on='hero_names')

hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics  203.0  441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0  ...           False
# 2       Abin Sur          DC Comics  185.0   90.0  ...           False
# 3    Abomination      Marvel Comics  203.0  441.0  ...           False
# 4  Absorbing Man      Marvel Comics  193.0  122.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 0        False       False              False       False       False
# 1        False       False              False       False       False
# 2        False       False              False       False       False
# 3        False       False              False       False       False
# 4        False       False              False       False       False
#
#    Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0          False               False    False           False
# 1          False               False    False           False
# 2          False               False    False           False
# 3          False               False    False           False
# 4          False               False    False           False
#
# [5 rows x 178 columns]

# %% [markdown]
# II. Use your combined DataFrame to answer the following questions.
#
# 1. Compare the average weight of super powers who have Super Speed to those who do not.

# %%
# With super speed
speed = hero_df['Super Speed'] == True

speed_df = hero_df[speed]

speed_df
# Out:
#      Gender               Race Alignment Hair color Eye color Skin color  \
# 3      Male  Human / Radiation       bad    No Hair     green    Unknown
# 5      Male              Human      good      Blond      blue    Unknown
# 8      Male            Unknown       bad      White      blue    Unknown
# 9      Male             Cyborg       bad      Black     brown    Unknown
# 10     Male            Unknown      good      Blond      blue    Unknown
# ..      ...                ...       ...        ...       ...        ...
# 453  Female           Demi-God      good      Blond      blue    Unknown
# 454    Male            Unknown      good      Black       red    Unknown
# 455  Female             Amazon      good      Black      blue    Unknown
# 460    Male     Yoda's species      good      White     brown      green
# 462    Male            Unknown       bad      Brown       red    Unknown
#
#              Hero      Publisher Height Weight  ... Weather Control  \
# 3     Abomination  Marvel Comics  203.0  441.0  ...           False
# 5    Adam Strange      DC Comics  185.0   88.0  ...           False
# 8      Air-Walker  Marvel Comics  188.0  108.0  ...           False
# 9            Ajax  Marvel Comics  193.0   90.0  ...           False
# 10     Alan Scott      DC Comics  180.0   90.0  ...           False
# ..            ...            ...    ...    ...  ...             ...
# 453   Wonder Girl      DC Comics  165.0   51.0  ...           False
# 454    Wonder Man  Marvel Comics  188.0  171.0  ...           False
# 455  Wonder Woman      DC Comics  183.0   74.0  ...           False
# 460          Yoda   George Lucas   66.0   17.0  ...           False
# 462          Zoom      DC Comics  185.0   81.0  ...           False
#
#      Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 3          False       False              False       False       False
# 5          False       False              False       False       False
# 8          False       False              False       False       False
# 9          False       False              False       False       False
# 10         False       False              False       False       False
# ..           ...         ...                ...         ...         ...
# 453        False       False              False       False       False
# 454        False       False              False       False       False
# 455        False       False              False       False       False
# 460        False       False              False       False       False
# 462        False       False              False       False       False
#
#      Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 3            False               False    False           False
# 5            False               False    False           False
# 8            False               False    False           False
# 9            False               False    False           False
# 10           False               False    False           False
# ..             ...                 ...      ...             ...
# 453          False               False    False           False
# 454          False               False    False           False
# 455          False               False    False           False
# 460          False               False    False           False
# 462          False               False    False           False
#
# [198 rows x 178 columns]

# %%
# weights
speed_df['Weight'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 3      441.0
# 5       88.0
# 8      108.0
# 9       90.0
# 10      90.0
#        ...
# 453     51.0
# 454    171.0
# 455     74.0
# 460     17.0
# 462     81.0
# Name: Weight, Length: 198, dtype: object>

# %%
no_speed_df = hero_df[~speed]
# Out:
# 265

# %%
no_speed_df['Weight'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      441.0
# 1       65.0
# 2       90.0
# 4      122.0
# 6       81.0
#        ...
# 456     50.0
# 457     61.0
# 458     83.0
# 459     52.0
# 461     57.0
# Name: Weight, Length: 265, dtype: object>

# %% [markdown]
# 2. What is the average height of heroes for each publisher?

# %%
height = hero_df.groupby('Publisher')['Height'].mean()
height.sort_values()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1763, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1762 try:
# -> 1763     result = self.grouper._cython_operation(
#    1764         "aggregate",
#    1765         values,
#    1766         how,
#    1767         axis=data.ndim - 1,
#    1768         min_count=min_count,
#    1769         **kwargs,
#    1770     )
#    1771 except NotImplementedError:
#    1772     # generally if we have numeric_only=False
#    1773     # and non-applicable functions
#    1774     # try to python agg
#    1775     # TODO: shouldn't min_count matter?
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# -> 1039 return cy_op.cython_operation(
#    1040     values=values,
#    1041     axis=axis,
#    1042     min_count=min_count,
#    1043     comp_ids=ids,
#    1044     ngroups=ngroups,
#    1045     **kwargs,
#    1046 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/ops.py:708, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     700     return self._ea_wrap_cython_operation(
#     701         values,
#     702         min_count=min_count,
#    (...)
#     705         **kwargs,
#     706     )
# --> 708 return self._cython_op_ndim_compat(
#     709     values,
#     710     min_count=min_count,
#     711     ngroups=ngroups,
#     712     comp_ids=comp_ids,
#     713     mask=None,
#     714     **kwargs,
#     715 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/ops.py:512, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     511     result_mask = result_mask[None, :]
# --> 512 res = self._call_cython_op(
#     513     values2d,
#     514     min_count=min_count,
#     515     ngroups=ngroups,
#     516     comp_ids=comp_ids,
#     517     mask=mask,
#     518     result_mask=result_mask,
#     519     **kwargs,
#     520 )
#     521 if res.shape[0] == 1:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/ops.py:571, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     570 out_shape = self._get_output_shape(ngroups, values)
# --> 571 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     572 values = self._get_cython_vals(values)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/ops.py:192, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     190 elif "object" not in f.__signatures__:
#     191     # raise NotImplementedError here rather than TypeError later
# --> 192     raise NotImplementedError(
#     193         f"function is not implemented for this dtype: "
#     194         f"[how->{how},dtype->{dtype_str}]"
#     195     )
#     196 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '185.0185.0180.0257.0183.0178.0185.0198.0178.0168.0183.0203.0170.0165.0168.0188.0178.0178.0173.0188.0191.0191.0165.0170.0185.0188.0183.0196.0198.0170.0170.0193.0193.0175.0175.0163.0170.0175.0183.0198.0267.0183.0185.0193.0188.0175.0244.0185.0168.0193.0188.0180.0183.0183.0157.062.5198.0178.0188.0188.0188.0170.0185.0175.0185.0180.0180.0170.0185.0196.0173.0244.0234.064.0180.0188.0165.0155.0191.0229.0201.0180.0175.0196.0185.0185.0183.0178.0183.0193.0178.0178.0157.0168.0185.0168.0168.0180.0180.0188.0193.0165.0178.0180.0183.0165.0185.0185.0178.0183.0165.0137.0168.0183.0173.0201.0175.0279.0188.0193.0165.0170.0201.0183.0170.0180.0165.0191.0188.0183.0168.0178.0175.0173.0165.0183.0170.0185.0'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [32], line 1
# ----> 1 height = hero_df.groupby('Publisher')['Height'].mean()
#       2 height.sort_values()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:2152, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2150     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2151 else:
# -> 2152     result = self._cython_agg_general(
#    2153         "mean",
#    2154         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2155         numeric_only=numeric_only,
#    2156     )
#    2157     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1782, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1778     return result
#    1780 # TypeError -> we may have an exception in trying to aggregate
#    1781 #  continue and exclude the block
# -> 1782 new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1784 if not is_ser and len(new_mgr) < orig_len:
#    1785     warn_dropping_nuisance_columns_deprecated(type(self), how, numeric_only)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1776, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1763     result = self.grouper._cython_operation(
#    1764         "aggregate",
#    1765         values,
#    (...)
#    1769         **kwargs,
#    1770     )
#    1771 except NotImplementedError:
#    1772     # generally if we have numeric_only=False
#    1773     # and non-applicable functions
#    1774     # try to python agg
#    1775     # TODO: shouldn't min_count matter?
# -> 1776     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1778 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1717, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1712     ser = df.iloc[:, 0]
#    1714 # We do not get here with UDFs, so we know that our dtype
#    1715 #  should always be preserved by the implemented aggregations
#    1716 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1717 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1719 if isinstance(values, Categorical):
#    1720     # Because we only get here with known dtype-preserving
#    1721     #  reductions, we cast back to Categorical.
#    1722     # TODO: if we ever get "rank" working, exclude it here.
#    1723     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1081, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#    1078     preserve_dtype = True
#    1080 else:
# -> 1081     result = self._aggregate_series_pure_python(obj, func)
#    1083 npvalues = lib.maybe_convert_objects(result, try_float=False)
#    1084 if preserve_dtype:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/ops.py:1104, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1101 splitter = get_splitter(obj, ids, ngroups, axis=0)
#    1103 for i, group in enumerate(splitter):
# -> 1104     res = func(group)
#    1105     res = libreduction.extract_result(res)
#    1107     if not initialized:
#    1108         # We only do this validation on the first iteration
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:2154, in GroupBy.mean.<locals>.<lambda>(x)
#    2150     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2151 else:
#    2152     result = self._cython_agg_general(
#    2153         "mean",
# -> 2154         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2155         numeric_only=numeric_only,
#    2156     )
#    2157     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
#   11402         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/nanops.py:706, in nanmean(values, axis, skipna, mask)
#     703     dtype_count = dtype
#     705 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     708 if axis is not None and getattr(the_sum, "ndim", False):
#     709     count = cast(np.ndarray, count)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages/pandas/core/nanops.py:1637, in _ensure_numeric(x)
#    1634             x = complex(x)
#    1635         except ValueError as err:
#    1636             # e.g. "foo"
# -> 1637             raise TypeError(f"Could not convert {x} to numeric") from err
#    1638 return x
#
# TypeError: Could not convert 185.0185.0180.0257.0183.0178.0185.0198.0178.0168.0183.0203.0170.0165.0168.0188.0178.0178.0173.0188.0191.0191.0165.0170.0185.0188.0183.0196.0198.0170.0170.0193.0193.0175.0175.0163.0170.0175.0183.0198.0267.0183.0185.0193.0188.0175.0244.0185.0168.0193.0188.0180.0183.0183.0157.062.5198.0178.0188.0188.0188.0170.0185.0175.0185.0180.0180.0170.0185.0196.0173.0244.0234.064.0180.0188.0165.0155.0191.0229.0201.0180.0175.0196.0185.0185.0183.0178.0183.0193.0178.0178.0157.0168.0185.0168.0168.0180.0180.0188.0193.0165.0178.0180.0183.0165.0185.0185.0178.0183.0165.0137.0168.0183.0173.0201.0175.0279.0188.0193.0165.0170.0201.0183.0170.0180.0165.0191.0188.0183.0168.0178.0175.0173.0165.0183.0170.0185.0 to numeric
